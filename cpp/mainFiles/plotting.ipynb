# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Example 2 rectangle

# %%
# Defining the data explicitly
h = np.array([0.1, 0.05, 0.025, 0.0125, 0.00625])
err_p_set_RT1 = np.array([1.409150e-03, 5.560870e-05, 1.064650e-05, 2.150670e-06, 4.840040e-07])
err_u_set_RT1 = np.array([4.320000e-04, 1.040000e-04, 2.500000e-05, 6.000000e-06, 1.500000e-06])
cond_nums_set_RT1 = np.array([
2.60E+05,
8.91E+05,
3.31E+06,
1.33E+07,
5.35E+07])  # Replace with actual values
err_p_set_RT0 = np.array([0.105872, 0.001900, 0.000761, 0.000365, 0.000181])
err_u_set_RT0 = np.array([0.023370, 0.005474, 0.002573, 0.001271, 0.000634])
cond_nums_set_RT0 = np.array([
4.86E+04,
1.54E+05,
5.22E+05,
1.90E+06,
7.18E+06])
err_p_set_fittedRT0 = np.array([
0.00290268 ,
0.00145223 ,
0.000726229,
0.000363129,
0.000181566])
err_u_set_fittedRT0 = np.array([
0.0103908  ,
0.0052051  ,
0.00260376 ,
0.00130203 ,
0.000651035])
cond_nums_set_fittedRT0 = np.array([
1.18E+03,
6.13E+03,
2.63E+04,
1.28E+05,
5.53E+05])
err_p_set_fittedRT1 = np.array([
0.00011829 ,
2.96622e-05,
7.42115e-06,
1.85564e-06,
4.63931e-07
])
err_u_set_fittedRT1 = np.array([
0.000401338,
0.000100335,
2.50837e-05,
6.27091e-06,
1.56773e-06])
cond_nums_set_fittedRT1 = np.array([
9.92E+03,
3.97E+04,
1.59E+05,
6.35E+05,
2.54E+06])

# Constants for reference lines
C_h2_set_RT1 = err_p_set_RT1[1] / h[1]**2
C_h_set_RT0 = err_p_set_RT0[1] / h[1]
C_h_u = err_u_set_RT0[0] / h[0]
C_h2_set_RT0 = err_u_set_RT1[0] / h[0]**2
C_h_inv_2_set_RT1 = cond_nums_set_RT1[0] * h[0]**2
C_h_inv_2_set_RT0 = cond_nums_set_RT0[0] * h[0]**2

# Reference lines
ref_line_h2_set_RT1 = C_h2_set_RT1 * h**2
ref_line_h_set_RT0 = C_h_set_RT0 * h
ref_line_h_u = C_h_u * h
ref_line_h2_set_RT0 = C_h2_set_RT0 * h**2
ref_line_h_inv_2_set_RT1 = C_h_inv_2_set_RT1 / h**2
ref_line_h_inv_2_set_RT0 = C_h_inv_2_set_RT0 / h**2

# Plotting the first three plots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

mksize = 10

# Plot for error in p
axs[0].loglog(h, err_p_set_RT1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_RT0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[0].loglog(h, err_p_set_fittedRT1, 'o-', color='seagreen', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_fittedRT0, 's-', color='seagreen', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[0].loglog(h, ref_line_h2_set_RT1, 'k-.', label='$O(h^2)$')
axs[0].loglog(h, ref_line_h_set_RT0, 'k--', label='$O(h)$')
axs[0].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[0].set_ylabel('$||p-p_h||_{L^2(\\Omega)}$', fontsize=16)
axs[0].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[0].tick_params(axis='both', labelsize=14)

# Plot for error in u
axs[1].loglog(h, err_u_set_RT1, 'o-', color='blue', markersize=mksize)
axs[1].loglog(h, err_u_set_RT0, 's-', color='blue', markersize=mksize)
axs[1].loglog(h, err_u_set_fittedRT1, 'o-', color='seagreen', markersize=mksize)
axs[1].loglog(h, err_u_set_fittedRT0, 's-', color='seagreen', markersize=mksize)
axs[1].loglog(h, ref_line_h2_set_RT0, 'k-.')
axs[1].loglog(h, ref_line_h_u, 'k--')
axs[1].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[1].set_ylabel('$||\\mathbf{u}-\\mathbf{u}_h||_{L^2(\\Omega)}$', fontsize=16)
axs[1].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[1].tick_params(axis='both', labelsize=14)

# Plot for condition numbers
axs[2].loglog(h, cond_nums_set_RT1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_RT0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_fittedRT1, 'o-', color='seagreen', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_fittedRT0, 's-', color='seagreen', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[2].loglog(h, ref_line_h_inv_2_set_RT1, 'k--.', label='$O(h^{-2})$ (set 1)')
axs[2].loglog(h, ref_line_h_inv_2_set_RT0, 'k--.', label='$O(h^{-2})$ (set 2)')
axs[2].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[2].set_ylabel('Condition Number', fontsize=16)
axs[2].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[2].tick_params(axis='both', labelsize=14)

# Adjusting layout
plt.tight_layout()
plt.subplots_adjust(bottom=0.15)

# Show the plots
# plt.show()

# Saving the plots to a PDF file
plt.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example1/convergence_all.pdf", format='pdf')

# %%
# Legend

# Creating the plot objects
line1, = plt.plot([], [], 's-', color='blue', label='$\\mathbf{RT}_0$')
line2, = plt.plot([], [], 'o-', color='blue', label='$\\mathbf{RT}_1$')
line11, = plt.plot([], [], 's-', color='seagreen', label='$\\mathbf{RT}_0$ fitted')
line22, = plt.plot([], [], 'o-', color='seagreen', label='$\\mathbf{RT}_1$ fitted')
line3, = plt.plot([], [], 'k--', label='$O(h)$')
line4, = plt.plot([], [], 'k-.', label='$O(h^2)$')
line5, = plt.plot([], [], 'k--.', label='$O(h^{-2})$')

# Creating the legend PDF for the first three plots
fig_legend_first_three, ax_legend_first_three = plt.subplots(figsize=(5, 1))
ax_legend_first_three.axis('off')
legend_first_three = fig_legend_first_three.legend(handles=[line1, line2, line11, line22, line3, line4, line5], loc='center', ncol=5)
fig_legend_first_three.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example1/legend_conv.pdf", format='pdf', bbox_extra_artists=(legend_first_three,), bbox_inches='tight')

# %%
# Defining the data explicitly
h = np.array([0.1, 0.05, 0.025, 0.0125, 0.00625])
err_divu_RT_1 = np.array([1.96598e-14,
2.28703e-14,
5.11183e-14,
7.00751e-14,
1.5223e-13 ])
err_maxdivu_RT_1 = np.array([2.50022e-13,
4.66405e-13,
1.79901e-12,
3.75344e-12,
1.68567e-11])
err_divu_RT_0 = np.array([0.0516535, 
0.0183329, 
0.00757011,
0.00361539,
0.00178845])
err_maxdivu_RT_0 = np.array([0.468489, 
0.246554, 
0.103409, 
0.05101,  
0.0253449])
err_divu_fittedRT_1 = np.array([
2.06695e-15,
4.20759e-15,
7.94171e-15,
1.54535e-14,
3.23636e-14])
err_maxdivu_fittedRT_1 = np.array([
1.51545e-14,
3.26961e-14,
9.02056e-14,
1.50477e-13,
3.58907e-13])
err_divu_fittedRT_0 = np.array([
0.0288675 , 
0.0144338 , 
0.00721688,
0.00360844,
0.00180422])
err_maxdivu_fittedRT_0 = np.array([
0.069614   , 
0.034807   , 
0.0174035  , 
0.00870176  ,  
0.00435088])

# Creating the new adjusted O(h) and O(h^2) reference lines
ref_line_h_err_divu = err_divu_RT_0[-1] / h[-1] * h
# ref_line_h2_err_divu = err_divu_RT_1[-1] / h[-1]**2 * h**2
ref_line_h_err_maxdivu = err_maxdivu_RT_0[-1] / h[-1] * h
# ref_line_h2_err_maxdivu = err_maxdivu_RT_1[-1] / h[-1]**2 * h**2

# Creating new plots with the updated y-labels
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
mksize = 10

# Plot for err_divu
axs[0].loglog(h, err_divu_RT_0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[0].loglog(h, err_divu_RT_1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_divu_fittedRT_0, 's-', color='seagreen', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[0].loglog(h, err_divu_fittedRT_1, 'o-', color='seagreen', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, ref_line_h_err_divu, 'k--', label='$O(h)$')
# axs[0].loglog(h, ref_line_h2_err_divu, 'k-.', label='$O(h^2)$')
axs[0].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[0].set_ylabel('$||\\nabla \\cdot \\mathbf{u} - \\nabla \\cdot \\mathbf{u}_h||_{L^2(\\Omega)}$', fontsize=16)
axs[0].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[0].tick_params(axis='both', labelsize=14)

# Plot for err_maxdivu
axs[1].loglog(h, err_maxdivu_RT_0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[1].loglog(h, err_maxdivu_RT_1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[1].loglog(h, err_maxdivu_fittedRT_0, 's-', color='seagreen', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[1].loglog(h, err_maxdivu_fittedRT_1, 'o-', color='seagreen', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[1].loglog(h, ref_line_h_err_maxdivu, 'k--', label='$O(h)$')
# axs[1].loglog(h, ref_line_h2_err_maxdivu, 'k-.', label='$O(h^2)$')
axs[1].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[1].set_ylabel('$||\\nabla \\cdot \\mathbf{u} - \\nabla \\cdot \\mathbf{u}_h||_{L^\\infty(\\Omega)}$', fontsize=16)
axs[1].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[1].tick_params(axis='both', labelsize=14)

# Adjusting layout and showing the plots
plt.tight_layout()
# plt.show()

# Saving the plots to a PDF file
plt.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example1/div_all.pdf", format='pdf')

# %%
line1, = plt.plot([], [], 's-', color='blue', label='$\\mathbf{RT}_0$')
line2, = plt.plot([], [], 'o-', color='blue', label='$\\mathbf{RT}_1$')
line11, = plt.plot([], [], 's-', color='seagreen', label='$\\mathbf{RT}_0$ fitted')
line22, = plt.plot([], [], 'o-', color='seagreen', label='$\\mathbf{RT}_1$ fitted')
line3, = plt.plot([], [], 'k--', label='$O(h)$')
line4, = plt.plot([], [], 'k-.', label='$O(h^2)$')

# Adding a shared legend at the bottom
fig_legend, ax_legend = plt.subplots(figsize=(4, 1))
ax_legend.axis('off')
legend = fig_legend.legend(handles=[line1, line2, line11, line22, line3, line4], loc='center', ncol=4)
fig_legend.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example1/legend_div.pdf", format='pdf', bbox_extra_artists=(legend_first_three,), bbox_inches='tight')

# %% [markdown]
# # Example 1 circle

# %%
# Re-defining the data and settings for the first set of plots
h = np.array([0.1, 0.05, 0.025, 0.0125, 0.00625])

# Set 1 (RT_1)
err_p_set_RT1 = np.array([
0.0220478  ,
0.00371086 ,
0.000730421,
0.000167286,
4.02971e-05
])
err_u_set_RT1 = np.array([
0.220233   ,
0.0323643  ,
0.00492156 ,
0.00105622 ,
0.000249106
])
cond_nums_set_RT1 = np.array([
2.01E+06, 
5.89E+06, 
1.99E+07, 
6.89E+07, 
2.70E+08])

# Set 11 (RT_1 altstab)
err_p_set_altRT1 = np.array([
0.0196304  ,
0.00352037 ,
0.000731921,
0.000167819,
4.03774e-05
])
err_u_set_altRT1 = np.array([
0.188672   ,
0.0271706  ,
0.00487383 ,
0.00107042 ,
0.000256805
])
cond_nums_set_altRT1 = np.array([
    1.69E+06, 
    3.23E+06, 
    1.10E+07, 
    4.10E+07, 
    1.54E+08])

# Set 2 (RT_0)
err_p_set_RT0 = np.array([0.110934, 0.0485721, 0.0223918, 0.0109056, 0.00540814])
err_u_set_RT0 = np.array([0.774027, 0.348116, 0.162576, 0.0793, 0.0392918])
cond_nums_set_RT0 = np.array([
    1.71E+04, 
    5.28E+04, 
    2.28E+05, 
    1.11E+06, 
    4.91E+06])

# Constants for reference lines
C_h2_set_RT1 = err_p_set_RT1[0] / h[0]**2
C_h_set_RT0 = err_p_set_RT0[0] / h[0]
C_h_u = err_u_set_RT0[0] / h[0]
C_h2_set_RT0 = err_u_set_RT1[0] / h[0]**2
C_h_inv_2_set_RT1 = cond_nums_set_RT1[0] * h[0]**2
C_h_inv_2_set_RT0 = cond_nums_set_RT0[0] * h[0]**2

# Reference lines
ref_line_h2_set_RT1 = C_h2_set_RT1 * h**2
ref_line_h_set_RT0 = C_h_set_RT0 * h
ref_line_h_u = C_h_u * h
ref_line_h2_set_RT0 = C_h2_set_RT0 * h**2
ref_line_h_inv_2_set_RT1 = C_h_inv_2_set_RT1 / h**2
ref_line_h_inv_2_set_RT0 = C_h_inv_2_set_RT0 / h**2


# Plotting the first three plots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
mksize = 10

# Plot for error in p
axs[0].loglog(h, err_p_set_RT1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_altRT1, 'o-', color='#FF6133', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_RT0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[0].loglog(h, ref_line_h2_set_RT1, 'k-.', label='$O(h^2)$')
axs[0].loglog(h, ref_line_h_set_RT0, 'k--', label='$O(h)$')
axs[0].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[0].set_ylabel('$||p-p_h||_{L^2(\\Omega)}$', fontsize=16)
axs[0].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[0].tick_params(axis='both', labelsize=14)

# Plot for error in u
axs[1].loglog(h, err_u_set_RT1, 'o-', color='blue', markersize=mksize)
axs[1].loglog(h, err_u_set_altRT1, 'o-', color='#FF6133', markersize=mksize)
axs[1].loglog(h, err_u_set_RT0, 's-', color='blue', markersize=mksize)
axs[1].loglog(h, ref_line_h2_set_RT0, 'k-.')
axs[1].loglog(h, ref_line_h_u, 'k--')
axs[1].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[1].set_ylabel('$||\\mathbf{u}-\\mathbf{u}_h||_{L^2(\\Omega)}$', fontsize=16)
axs[1].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[1].tick_params(axis='both', labelsize=14)

# Plot for condition numbers
axs[2].loglog(h, cond_nums_set_RT1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_altRT1, 'o-', color='#FF6133', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_RT0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[2].loglog(h, ref_line_h_inv_2_set_RT1, 'k--.', label='$O(h^{-2})$ (set 1)')
axs[2].loglog(h, ref_line_h_inv_2_set_RT0, 'k--.', label='$O(h^{-2})$ (set 2)')
axs[2].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[2].set_ylabel('Condition Number', fontsize=16)
axs[2].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[2].tick_params(axis='both', labelsize=14)

# Adjusting layout
plt.tight_layout()
plt.subplots_adjust(bottom=0.15)

# Saving the plots to a PDF file
plt.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example2/convergence_all.pdf", format='pdf')

# %%
# Legend

# Creating the plot objects
line1, = plt.plot([], [], 's-', color='blue', label='$\\mathbf{RT}_0$')
line2, = plt.plot([], [], 'o-', color='blue', label='$\\mathbf{RT}_1$')
line22, = plt.plot([], [], 'o-', color='#FF6133', label='$\\mathbf{RT}_1\ \hat s_c$')
line3, = plt.plot([], [], 'k--', label='$O(h)$')
line4, = plt.plot([], [], 'k-.', label='$O(h^2)$')
line5, = plt.plot([], [], 'k--.', label='$O(h^{-2})$')

# Creating the legend PDF for the first three plots
fig_legend_first_three, ax_legend_first_three = plt.subplots(figsize=(5, 1))
ax_legend_first_three.axis('off')
legend_first_three = fig_legend_first_three.legend(handles=[line1, line2, line22, line3, line4, line5], loc='center', ncol=5)
fig_legend_first_three.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example2/legend_conv.pdf", format='pdf', bbox_extra_artists=(legend_first_three,), bbox_inches='tight')

# %%
# Given data for RT_1
err_divu_RT_0 = [7.77248, 3.66092, 1.75339, 0.859624, 0.42693]
err_maxdivu_RT_0 = [43.9099, 21.2993, 10.6092, 5.53376, 2.83981]

# Given data for RT_1
err_divu_RT_1 = [
1.10716   ,
0.253164  ,
0.0568281 ,
0.0131846 ,
0.00318057
]
err_maxdivu_RT_1 = [
11.3845  ,
3.27079  ,
1.00433  ,
0.248071 ,
0.0649852
]

# Given data for RT_1 altstab
err_divu_altRT_1 = [
1.10716   ,
0.253164  ,
0.0568281 ,
0.0131846 ,
0.00318057
]
err_maxdivu_altRT_1 = [
11.3845  ,
3.27079  ,
1.00433  ,
0.248071 ,
0.0649852
]

# Creating the new adjusted O(h) and O(h^2) reference lines
ref_line_h_err_divu = err_divu_RT_0[-1] / h[-1] * h
ref_line_h2_err_divu = err_divu_RT_1[-1] / h[-1]**2 * h**2
ref_line_h_err_maxdivu = err_maxdivu_RT_0[-1] / h[-1] * h
ref_line_h2_err_maxdivu = err_maxdivu_RT_1[-1] / h[-1]**2 * h**2

# Creating new plots with the updated y-labels
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot for err_divu
axs[0].loglog(h, err_divu_RT_0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[0].loglog(h, err_divu_RT_1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=1.4*mksize)
axs[0].loglog(h, err_divu_altRT_1, 'o-', color='#FF6133', label='$\\mathbf{RT}_1$ altstab', markersize=mksize)
axs[0].loglog(h, ref_line_h_err_divu, 'k--', label='$O(h)$')
axs[0].loglog(h, ref_line_h2_err_divu, 'k-.', label='$O(h^2)$')
axs[0].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[0].set_ylabel('$||\\nabla \\cdot \\mathbf{u} - \\nabla \\cdot \\mathbf{u}_h||_{L^2(\\Omega)}$', fontsize=16)
axs[0].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[0].tick_params(axis='both', labelsize=14)

# Plot for err_maxdivu
axs[1].loglog(h, err_maxdivu_RT_0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[1].loglog(h, err_maxdivu_RT_1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=1.4*mksize)
axs[1].loglog(h, err_maxdivu_altRT_1, 'o-', color='#FF6133', label='$\\mathbf{RT}_1$ altstab', markersize=mksize)
axs[1].loglog(h, ref_line_h_err_maxdivu, 'k--', label='$O(h)$')
axs[1].loglog(h, ref_line_h2_err_maxdivu, 'k-.', label='$O(h^2)$')
axs[1].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[1].set_ylabel('$||\\nabla \\cdot \\mathbf{u} - \\nabla \\cdot \\mathbf{u}_h||_{L^\\infty(\\Omega)}$', fontsize=16)
axs[1].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[1].tick_params(axis='both', labelsize=14)

plt.tight_layout()
# plt.show()
fig.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example2/div_all.pdf", format='pdf')

# %%
line1, = plt.plot([], [], 's-', color='blue', label='$\\mathbf{RT}_0$')
line2, = plt.plot([], [], 'o-', color='blue', label='$\\mathbf{RT}_1$')
line22, = plt.plot([], [], 'o-', color='#FF6133', label='$\\mathbf{RT}_1\ \hat s_c$')
line3, = plt.plot([], [], 'k--', label='$O(h)$')
line4, = plt.plot([], [], 'k-.', label='$O(h^2)$')

# Adding a shared legend at the bottom
fig_legend, ax_legend = plt.subplots(figsize=(4, 1))
ax_legend.axis('off')
legend = fig_legend.legend(handles=[line1, line2, line22, line3, line4], loc='center', ncol=4)
fig_legend.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example2/legend_div.pdf", format='pdf', bbox_extra_artists=(legend_first_three,), bbox_inches='tight')

# %% [markdown]
# # Example 1 circle (three data comparison)

# %%
# Re-defining the data and settings for the first set of plots
h = np.array([0.1, 0.05, 0.025, 0.0125, 0.00625])

# Set 1 (RT_1)
err_p_set_RT1 = np.array([
0.0196304  ,
0.00352037 ,
0.000731921,
0.000167819,
4.03774e-05
])
err_u_set_RT1 = np.array([
0.188672   ,
0.0271706  ,
0.00487383 ,
0.00107042 ,
0.000256805
])
cond_nums_set_RT1 = np.array([
1.69E+06, 
3.23E+06, 
1.10E+07, 
4.10E+07, 
1.54E+08])

# Set 11 (RT_1 altstab)
err_p_set_altRT1 = np.array([
0.0166511  ,
0.00332941 ,
0.000726047,
0.00016733 ,
4.03082e-05
])
err_u_set_altRT1 = np.array([
0.107862   ,
0.0223118  ,
0.00481417 ,
0.00107631 ,
0.000255087
])
cond_nums_set_altRT1 = np.array([
7.29E+07, 
9.15E+07, 
7.48E+08, 
5.50E+08, 
3.24E+09])

# Set 111 (RT_1 altstab)
err_p_set_altbadRT1 = np.array([
0.0164461  ,
0.00332842 ,
0.000726453,
0.000167407,
4.03266e-05
])
err_u_set_altbadRT1 = np.array([
0.109654   ,
0.0223518  ,
0.00531093 ,
0.00123635 ,
0.000521802
])
cond_nums_set_altbadRT1 = np.array([
1.58E+06, 
2.14E+06, 
9.69E+06, 
2.40E+07, 
7.74E+07])

# Set 2 (RT_0)
err_p_set_RT0 = np.array([0.110934, 0.0485721, 0.0223918, 0.0109056, 0.00540814])
err_u_set_RT0 = np.array([0.774027, 0.348116, 0.162576, 0.0793, 0.0392918])
cond_nums_set_RT0 = np.array([
    1.71E+04, 
    5.28E+04, 
    2.28E+05, 
    1.11E+06, 
    4.91E+06])

# Constants for reference lines
C_h2_set_RT1 = err_p_set_RT1[0] / h[0]**2
C_h_set_RT0 = err_p_set_RT0[0] / h[0]
C_h_u = err_u_set_RT0[0] / h[0]
C_h2_set_RT0 = err_u_set_RT1[0] / h[0]**2
C_h_inv_2_set_RT1 = cond_nums_set_RT1[0] * h[0]**2
C_h_inv_2_set_RT0 = cond_nums_set_RT0[0] * h[0]**2

# Reference lines
ref_line_h2_set_RT1 = C_h2_set_RT1 * h**2
ref_line_h_set_RT0 = C_h_set_RT0 * h
ref_line_h_u = C_h_u * h
ref_line_h2_set_RT0 = C_h2_set_RT0 * h**2
ref_line_h_inv_2_set_RT1 = C_h_inv_2_set_RT1 / h**2
ref_line_h_inv_2_set_RT0 = C_h_inv_2_set_RT0 / h**2


# Plotting the first three plots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
mksize = 10

# Plot for error in p
axs[0].loglog(h, err_p_set_RT1, 'o-', color='#FF6133', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_altRT1, 'o-', color='grey', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_altbadRT1, 'o-', color='black', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, ref_line_h2_set_RT1, 'k-.', label='$O(h^2)$')
axs[0].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[0].set_ylabel('$||p-p_h||_{L^2(\\Omega)}$', fontsize=16)
axs[0].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[0].tick_params(axis='both', labelsize=14)

# Plot for error in u
axs[1].loglog(h, err_u_set_RT1, 'o-', color='#FF6133', markersize=mksize)
axs[1].loglog(h, err_u_set_altRT1, 'o-', color='grey', markersize=mksize)
axs[1].loglog(h, err_u_set_altbadRT1, 'o-', color='black', markersize=mksize)
axs[1].loglog(h, ref_line_h2_set_RT0, 'k-.')
axs[1].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[1].set_ylabel('$||\\mathbf{u}-\\mathbf{u}_h||_{L^2(\\Omega)}$', fontsize=16)
axs[1].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[1].tick_params(axis='both', labelsize=14)

# Plot for condition numbers
axs[2].loglog(h, cond_nums_set_RT1, 'o-', color='#FF6133', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_altRT1, 'o-', color='grey', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_altbadRT1, 'o-', color='black', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, ref_line_h_inv_2_set_RT1, 'k--.', label='$O(h^{-2})$ (set 1)')
axs[2].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[2].set_ylabel('Condition Number', fontsize=16)
axs[2].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[2].tick_params(axis='both', labelsize=14)

# Adjusting layout
plt.tight_layout()
plt.subplots_adjust(bottom=0.15)

# Saving the plots to a PDF file
plt.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example2/convergence_alt_3.pdf", format='pdf')

# %%
# Legend

# Creating the plot objects
line1, = plt.plot([], [], 'o-', color='#FF6133', label='$\hat s_c$')
line2, = plt.plot([], [], 'o-', color='grey', label='$\overset{\sim}{s_c}$')
line22, = plt.plot([], [], 'o-', color='black', label='$\overset{\sim}{s_c}$ with $Q_1^{\Sigma}$')
line3, = plt.plot([], [], 'k-.', label='$O(h^2)$')
line4, = plt.plot([], [], 'k--.', label='$O(h^{-2})$')

# Creating the legend PDF for the first three plots
fig_legend_first_three, ax_legend_first_three = plt.subplots(figsize=(5, 1))
ax_legend_first_three.axis('off')
legend_first_three = fig_legend_first_three.legend(handles=[line1, line2, line22, line3, line4], loc='center', ncol=5)
fig_legend_first_three.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example2/legend_alt_3.pdf", format='pdf', bbox_extra_artists=(legend_first_three,), bbox_inches='tight')
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\h'
# <>:5: SyntaxWarning: invalid escape sequence '\o'
# <>:6: SyntaxWarning: invalid escape sequence '\o'
# <>:4: SyntaxWarning: invalid escape sequence '\h'
# <>:5: SyntaxWarning: invalid escape sequence '\o'
# <>:6: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_57217/2643632801.py:4: SyntaxWarning: invalid escape sequence '\h'
#   line1, = plt.plot([], [], 'o-', color='#FF6133', label='$\hat s_c$')
# /tmp/ipykernel_57217/2643632801.py:5: SyntaxWarning: invalid escape sequence '\o'
#   line2, = plt.plot([], [], 'o-', color='grey', label='$\overset{\sim}{s_c}$')
# /tmp/ipykernel_57217/2643632801.py:6: SyntaxWarning: invalid escape sequence '\o'
#   line22, = plt.plot([], [], 'o-', color='black', label='$\overset{\sim}{s_c}$ with $Q_1^{\Sigma}$')

# %% [markdown]
# # Example 1 circle (three data comparison edit with four data)

# %%
# Re-defining the data and settings for the first set of plots
h = np.array([0.1, 0.05, 0.025, 0.0125, 0.00625])

# Set 1 (RT_1)
err_p_set_RT1 = np.array([
0.0196304  ,
0.00352037 ,
0.000731921,
0.000167819,
4.03774e-05
])
err_u_set_RT1 = np.array([
0.188672   ,
0.0271706  ,
0.00487383 ,
0.00107042 ,
0.000256805
])
cond_nums_set_RT1 = np.array([
1.69E+06, 
3.23E+06, 
1.10E+07, 
4.10E+07, 
1.54E+08])


# Set 11 (RT_1 altstab)
err_p_set_altRT1 = np.array([
0.0166511  ,
0.00332941 ,
0.000726047,
0.00016733 ,
4.03082e-05
])
err_u_set_altRT1 = np.array([
0.107862   ,
0.0223118  ,
0.00481417 ,
0.00107631 ,
0.000255087
])
cond_nums_set_altRT1 = np.array([
7.29E+07, 
9.15E+07, 
7.48E+08, 
5.50E+08, 
3.24E+09])

# Set 111 (RT_1 altstab)
err_p_set_altbadRT1 = np.array([
0.0164461  ,
0.00332842 ,
0.000726453,
0.000167407,
4.03266e-05
])
err_u_set_altbadRT1 = np.array([
0.109654   ,
0.0223518  ,
0.00531093 ,
0.00123635 ,
0.000521802
])
cond_nums_set_altbadRT1 = np.array([
1.58E+06, 
2.14E+06, 
9.69E+06, 
2.40E+07, 
7.74E+07])

# Set 1.5 (RT_1)
err_p_set_redRT1 = np.array([
0.0260294  ,
0.0051819  ,
0.000934066,
0.000185984,
4.19589e-05
])
err_u_set_redRT1 = np.array([
0.27611    ,
0.0607828  ,
0.0104785  ,
0.00181358 ,
0.000444468
])
cond_nums_set_redRT1 = np.array([
3.96E+05, 
1.01E+06, 
3.52E+06, 
1.30E+07, 
5.01E+07])

# Set 2 (RT_0)
err_p_set_RT0 = np.array([0.110934, 0.0485721, 0.0223918, 0.0109056, 0.00540814])
err_u_set_RT0 = np.array([0.774027, 0.348116, 0.162576, 0.0793, 0.0392918])
cond_nums_set_RT0 = np.array([
    1.71E+04, 
    5.28E+04, 
    2.28E+05, 
    1.11E+06, 
    4.91E+06])

# Constants for reference lines
C_h2_set_RT1 = err_p_set_RT1[0] / h[0]**2
C_h_set_RT0 = err_p_set_RT0[0] / h[0]
C_h_u = err_u_set_RT0[0] / h[0]
C_h2_set_RT0 = err_u_set_RT1[0] / h[0]**2
C_h_inv_2_set_RT1 = cond_nums_set_RT1[0] * h[0]**2
C_h_inv_2_set_RT0 = cond_nums_set_RT0[0] * h[0]**2

# Reference lines
ref_line_h2_set_RT1 = C_h2_set_RT1 * h**2
ref_line_h_set_RT0 = C_h_set_RT0 * h
ref_line_h_u = C_h_u * h
ref_line_h2_set_RT0 = C_h2_set_RT0 * h**2
ref_line_h_inv_2_set_RT1 = C_h_inv_2_set_RT1 / h**2
ref_line_h_inv_2_set_RT0 = C_h_inv_2_set_RT0 / h**2


# Plotting the first three plots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
mksize = 10

# Plot for error in p
axs[0].loglog(h, err_p_set_RT1, 'o-', color='#FF6133', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_redRT1, 'o-', color='red', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_altRT1, 'o-', color='grey', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, err_p_set_altbadRT1, 'o-', color='black', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[0].loglog(h, ref_line_h2_set_RT1, 'k-.', label='$O(h^2)$')
axs[0].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[0].set_ylabel('$||p-p_h||_{L^2(\\Omega)}$', fontsize=16)
axs[0].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[0].tick_params(axis='both', labelsize=14)

# Plot for error in u
axs[1].loglog(h, err_u_set_RT1, 'o-', color='#FF6133', markersize=mksize)
axs[1].loglog(h, err_u_set_redRT1, 'o-', color='red', markersize=mksize)
axs[1].loglog(h, err_u_set_altRT1, 'o-', color='grey', markersize=mksize)
axs[1].loglog(h, err_u_set_altbadRT1, 'o-', color='black', markersize=mksize)
axs[1].loglog(h, ref_line_h2_set_RT0, 'k-.')
axs[1].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[1].set_ylabel('$||\\mathbf{u}-\\mathbf{u}_h||_{L^2(\\Omega)}$', fontsize=16)
axs[1].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[1].tick_params(axis='both', labelsize=14)

# Plot for condition numbers
axs[2].loglog(h, cond_nums_set_RT1, 'o-', color='#FF6133', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_redRT1, 'o-', color='red', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_altRT1, 'o-', color='grey', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_altbadRT1, 'o-', color='black', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, ref_line_h_inv_2_set_RT1, 'k--.', label='$O(h^{-2})$ (set 1)')
axs[2].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[2].set_ylabel('Condition Number', fontsize=16)
axs[2].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[2].tick_params(axis='both', labelsize=14)

# Adjusting layout
plt.tight_layout()
plt.subplots_adjust(bottom=0.15)

# Saving the plots to a PDF file
plt.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example2/convergence_alt_3.pdf", format='pdf')

# %%
# Legend

# Creating the plot objects
line1, = plt.plot([], [], 'o-', color='#FF6133', label='$\hat s_c$')
line11, = plt.plot([], [], 'o-', color='red', label='$\hat s_c$ with $Q_1^{\Sigma}$')
line2, = plt.plot([], [], 'o-', color='grey', label='$\overset{\sim}{s_c}$')
line22, = plt.plot([], [], 'o-', color='black', label='$\overset{\sim}{s_c}$ with $Q_1^{\Sigma}$')
line3, = plt.plot([], [], 'k-.', label='$O(h^2)$')
line4, = plt.plot([], [], 'k--.', label='$O(h^{-2})$')

# Creating the legend PDF for the first three plots
fig_legend_first_three, ax_legend_first_three = plt.subplots(figsize=(6, 1))
ax_legend_first_three.axis('off')
legend_first_three = fig_legend_first_three.legend(handles=[line1, line11, line2, line22, line3, line4], loc='center', ncol=6)
fig_legend_first_three.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example2/legend_alt_3.pdf", format='pdf', bbox_extra_artists=(legend_first_three,), bbox_inches='tight')
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\h'
# <>:5: SyntaxWarning: invalid escape sequence '\h'
# <>:6: SyntaxWarning: invalid escape sequence '\o'
# <>:7: SyntaxWarning: invalid escape sequence '\o'
# <>:4: SyntaxWarning: invalid escape sequence '\h'
# <>:5: SyntaxWarning: invalid escape sequence '\h'
# <>:6: SyntaxWarning: invalid escape sequence '\o'
# <>:7: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_57217/3789624880.py:4: SyntaxWarning: invalid escape sequence '\h'
#   line1, = plt.plot([], [], 'o-', color='#FF6133', label='$\hat s_c$')
# /tmp/ipykernel_57217/3789624880.py:5: SyntaxWarning: invalid escape sequence '\h'
#   line11, = plt.plot([], [], 'o-', color='red', label='$\hat s_c$ with $Q_1^{\Sigma}$')
# /tmp/ipykernel_57217/3789624880.py:6: SyntaxWarning: invalid escape sequence '\o'
#   line2, = plt.plot([], [], 'o-', color='grey', label='$\overset{\sim}{s_c}$')
# /tmp/ipykernel_57217/3789624880.py:7: SyntaxWarning: invalid escape sequence '\o'
#   line22, = plt.plot([], [], 'o-', color='black', label='$\overset{\sim}{s_c}$ with $Q_1^{\Sigma}$')

# %% [markdown]
# # Example 3

# %%
# Defining the data explicitly (set 1 = RT1, set 2 = RT0)
h = np.array([0.1, 0.05, 0.025, 0.0125, 0.00625])
err_p_set_RT1 = np.array([
0.0400641  ,
0.00765454 ,
0.00170109 ,
0.000391128,
9.39409e-05])
err_u_set_RT1 = np.array([
0.131384   , 
0.0314019  ,
0.00819939 ,
0.00203868 ,
0.000505064])
cond_nums_set_RT1 = np.array([
1.58E+07,
3.24E+07,
8.08E+07,
1.78E+08,
8.83E+08]) 

err_p_set_NitRT1 = np.array([
0.0387615  ,
0.00740629 ,
0.00166698 ,
0.00038702 ,
9.33863e-05])
err_u_set_NitRT1 = np.array([
0.145766   , 
0.0321352  ,
0.00823902 ,
0.00203103 ,
0.000500535])
cond_nums_set_NitRT1 = np.array([
1.95E+07,
7.96E+07,
3.64E+08,
1.52E+09,
8.02E+09])
# 2.19E+05,
# 3.79E+05,
# 9.55E+05,
# 2.68E+06,
# 1.09E+07])
# 3.952797e+09,
# 5.911261e+08,
# 1.325473e+09,
# 3.353338e+09,
# 7.595145e+09]) 

err_p_set_RT0 = np.array([
0.248023 , 
0.119173 ,
0.0571338,
0.0275079,
0.0134853])
err_u_set_RT0 = np.array([
0.0809479 ,
0.0298523 ,
0.00912636,
0.00293264,
0.00115425])
cond_nums_set_RT0 = np.array([
1.54E+04,
4.40E+04,
2.14E+05,
9.14E+05,
4.41E+06]) 

err_p_set_NitRT0 = np.array([
0.599007 , 
0.120985 ,
0.0581127,
0.0281891,
0.0139655])
err_u_set_NitRT0 = np.array([
0.08276  ,
0.0754373,
0.0524286,
0.0358965,
0.0240618])
cond_nums_set_NitRT0 = np.array([
3.16E+09,
3.54E+07,
1.72E+08,
8.50E+08,
4.12E+09]) 

# Constants for reference lines
C_h2_set_RT1 = err_p_set_RT1[0] / h[0]**2
C_h_set_RT0 = err_p_set_RT0[0] / h[0]
C_h_u = err_u_set_RT0[0] / h[0]
C_h2_set_RT0 = err_u_set_RT1[0] / h[0]**2
C_h_inv_2_set_RT1 = cond_nums_set_RT1[0] * h[0]**2
C_h_inv_2_set_RT0 = cond_nums_set_RT0[0] * h[0]**2

# Reference lines
ref_line_h2_set_RT1 = C_h2_set_RT1 * h**2
ref_line_h_set_RT0 = C_h_set_RT0 * h
ref_line_h_u = C_h_u * h
ref_line_h2_set_RT0 = C_h2_set_RT0 * h**2
ref_line_h_inv_2_set_RT1 = C_h_inv_2_set_RT1 / h**2
ref_line_h_inv_2_set_RT0 = C_h_inv_2_set_RT0 / h**2

# Plotting the first three plots
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

mksize = 10

# Plot for error in p
axs[0].loglog(h, err_p_set_RT1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=1.2*mksize)
axs[0].loglog(h, err_p_set_RT0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=1.2*mksize)
axs[0].loglog(h, err_p_set_NitRT1, 'o-', color='violet', label='$\\mathbf{RT}_1$ Nitsche', markersize=mksize)
axs[0].loglog(h, err_p_set_NitRT0, 's-', color='violet', label='$\\mathbf{RT}_0$ Nitsche', markersize=mksize)
axs[0].loglog(h, ref_line_h2_set_RT1, 'k-.', label='$O(h^2)$')
axs[0].loglog(h, ref_line_h_set_RT0, 'k--', label='$O(h)$')
axs[0].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[0].set_ylabel('$||p-p_h||_{L^2(\\Omega)}$', fontsize=16)
axs[0].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[0].tick_params(axis='both', labelsize=14)

# Plot for error in u
axs[1].loglog(h, err_u_set_RT1, 'o-', color='blue', markersize=1.2*mksize)
axs[1].loglog(h, err_u_set_RT0, 's-', color='blue', markersize=1.2*mksize)
axs[1].loglog(h, err_u_set_NitRT1, 'o-', color='violet', markersize=mksize)
axs[1].loglog(h, err_u_set_NitRT0, 's-', color='violet', markersize=mksize)
axs[1].loglog(h, ref_line_h2_set_RT0, 'k-.')
axs[1].loglog(h, ref_line_h_u, 'k--')
axs[1].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[1].set_ylabel('$||\\mathbf{u}-\\mathbf{u}_h||_{L^2(\\Omega)}$', fontsize=16)
axs[1].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[1].tick_params(axis='both', labelsize=14)

# Plot for condition numbers
axs[2].loglog(h, cond_nums_set_RT1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_RT0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=mksize)
axs[2].loglog(h, cond_nums_set_NitRT1, 'o-', color='violet', label='$\\mathbf{RT}_1$ Nitsche', markersize=mksize)
axs[2].loglog(h, cond_nums_set_NitRT0, 's-', color='violet', label='$\\mathbf{RT}_0$ Nitsche', markersize=mksize)
axs[2].loglog(h, ref_line_h_inv_2_set_RT1, 'k--.', label='$O(h^{-2})$ (set 1)')
axs[2].loglog(h, ref_line_h_inv_2_set_RT0, 'k--.', label='$O(h^{-2})$ (set 2)')
axs[2].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[2].set_ylabel('Condition Number', fontsize=16)
axs[2].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[2].tick_params(axis='both', labelsize=14)

# Adjusting layout
plt.tight_layout()
plt.subplots_adjust(bottom=0.15)

# Show the plots
# plt.show()

# Saving the plots to a PDF file
plt.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example3/convergence_all.pdf", format='pdf')

# %%
# Legend

# Creating the plot objects
line1, = plt.plot([], [], 's-', color='blue', label='$\\mathbf{RT}_0$')
line11, = plt.plot([], [], 's-', color='violet', label='$\\mathbf{RT}_0$ penalty')
line2, = plt.plot([], [], 'o-', color='blue', label='$\\mathbf{RT}_1$')
line22, = plt.plot([], [], 'o-', color='violet', label='$\\mathbf{RT}_1$ penalty')
line3, = plt.plot([], [], 'k--', label='$O(h)$')
line4, = plt.plot([], [], 'k-.', label='$O(h^2)$')
line5, = plt.plot([], [], 'k--.', label='$O(h^{-2})$')

# Creating the legend PDF for the first three plots
fig_legend_first_three, ax_legend_first_three = plt.subplots(figsize=(5, 1))
ax_legend_first_three.axis('off')
legend_first_three = fig_legend_first_three.legend(handles=[line1, line2, line11, line22, line3, line4, line5], loc='center', ncol=5)
fig_legend_first_three.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example3/legend_conv.pdf", format='pdf', bbox_extra_artists=(legend_first_three,), bbox_inches='tight')

# %%
# Defining the data explicitly
h = np.array([0.1, 0.05, 0.025, 0.0125, 0.00625])
err_divu_RT_1 = np.array([
0.0451365  ,
0.010423   ,
0.0022726  ,
0.000493373,
0.000112307])
err_maxdivu_RT_1 = np.array([
0.610766  ,
0.264281  ,
0.0872358 ,
0.0230297 ,
0.00613657])
err_divu_RT_0 = np.array([
0.239077 ,
0.126842 ,
0.0619645,
0.0299204,
0.0146235])
err_maxdivu_RT_0 = np.array([
2.24178 ,
1.59905 ,
1.05913 ,
0.594026,
0.318427])
err_divu_NitRT_1 = np.array([
0.0451365  ,
0.010423   ,
0.0022726  ,
0.000493373,
0.000112307])
err_maxdivu_NitRT_1 = np.array([
0.610766  ,
0.264281  ,
0.0872358 ,
0.0230297 ,
0.00613657])
err_divu_NitRT_0 = np.array([
0.239077 ,
0.126842 ,
0.0619645,
0.0299204,
0.0146235])
err_maxdivu_NitRT_0 = np.array([
2.24178 ,
1.59905 ,
1.05913 ,
0.594026,
0.318427])

# Creating the new adjusted O(h) and O(h^2) reference lines
ref_line_h_err_divu = err_divu_RT_0[-1] / h[-1] * h
ref_line_h2_err_divu = err_divu_RT_1[-1] / h[-1]**2 * h**2
ref_line_h_err_maxdivu = err_maxdivu_RT_0[-1] / h[-1] * h
ref_line_h2_err_maxdivu = err_maxdivu_RT_1[-1] / h[-1]**2 * h**2

# Creating new plots with the updated y-labels
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
mksize = 10

# Plot for err_divu
axs[0].loglog(h, err_divu_RT_0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=1.2*mksize)
axs[0].loglog(h, err_divu_RT_1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=1.2*mksize)
axs[0].loglog(h, err_divu_NitRT_0, 's-', color='violet', label='$\\mathbf{RT}_0$ Nitsche', markersize=mksize)
axs[0].loglog(h, err_divu_NitRT_1, 'o-', color='violet', label='$\\mathbf{RT}_1$ Nitsche', markersize=mksize)
axs[0].loglog(h, ref_line_h_err_divu, 'k--', label='$O(h)$')
axs[0].loglog(h, ref_line_h2_err_divu, 'k-.', label='$O(h^2)$')
axs[0].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[0].set_ylabel('$||\\nabla \\cdot \\mathbf{u} - \\nabla \\cdot \\mathbf{u}_h||_{L^2(\\Omega)}$', fontsize=16)
axs[0].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[0].tick_params(axis='both', labelsize=14)

# Plot for err_maxdivu
axs[1].loglog(h, err_maxdivu_RT_0, 's-', color='blue', label='$\\mathbf{RT}_0$', markersize=1.2*mksize)
axs[1].loglog(h, err_maxdivu_RT_1, 'o-', color='blue', label='$\\mathbf{RT}_1$', markersize=1.2*mksize)
axs[1].loglog(h, err_maxdivu_NitRT_0, 's-', color='violet', label='$\\mathbf{RT}_0$ Nitsche', markersize=mksize)
axs[1].loglog(h, err_maxdivu_NitRT_1, 'o-', color='violet', label='$\\mathbf{RT}_1$ Nitsche', markersize=mksize)
axs[1].loglog(h, ref_line_h_err_maxdivu, 'k--', label='$O(h)$')
axs[1].loglog(h, ref_line_h2_err_maxdivu, 'k-.', label='$O(h^2)$')
axs[1].set_xlabel('Mesh size ($h$)', fontsize=16)
axs[1].set_ylabel('$||\\nabla \\cdot \\mathbf{u} - \\nabla \\cdot \\mathbf{u}_h||_{L^\\infty(\\Omega)}$', fontsize=16)
axs[1].grid(True, which="both", linestyle='--', linewidth=0.5)
axs[1].tick_params(axis='both', labelsize=14)

# Adjusting layout and showing the plots
plt.tight_layout()
# plt.show()

# Saving the plots to a PDF file
plt.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example3/div_all.pdf", format='pdf')

# %%
line1, = plt.plot([], [], 's-', color='blue', label='$\\mathbf{RT}_0$')
line11, = plt.plot([], [], 's-', color='violet', label='$\\mathbf{RT}_0$ penalty')
line2, = plt.plot([], [], 'o-', color='blue', label='$\\mathbf{RT}_1$')
line22, = plt.plot([], [], 'o-', color='violet', label='$\\mathbf{RT}_1$ penalty')
line3, = plt.plot([], [], 'k--', label='$O(h)$')
line4, = plt.plot([], [], 'k-.', label='$O(h^2)$')

# Adding a shared legend at the bottom
fig_legend, ax_legend = plt.subplots(figsize=(4, 1))
ax_legend.axis('off')
legend = fig_legend.legend(handles=[line1, line2, line11, line22, line3, line4], loc='center', ncol=4)
fig_legend.savefig("/home/darth/Dropbox/KTH/ConservationCutFEM_Darcy/article_fictitious_domain/3field_symmetric_version/figure/example3/legend_div.pdf", format='pdf', bbox_extra_artists=(legend_first_three,), bbox_inches='tight')
